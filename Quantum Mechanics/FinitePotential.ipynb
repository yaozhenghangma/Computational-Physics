# %% [markdown]
# # Finite Potential
# ## Odd Parity

# %%
using SymPy
using Plots
pyplot()
# Out:
# Plots.PyPlotBackend()

# %%
r = 52.4231
@vars ξ θ
plot(-ξ*cot(ξ), 0.1, sqrt(r), ylim=(0.1, sqrt(r)), legend=false)
plot!(sqrt(r)*cos(θ), sqrt(r)*sin(θ), 0, pi/2, ylim=(0.1, sqrt(r)), legend=false)
